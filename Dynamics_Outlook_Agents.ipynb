# %% [markdown]
# ## Accessing Dynamics365 and Outlook365 With Autogen
#
# Prerequisites
# - Access to Dynamics365 with Service Principles and appropriate access. Refer to https://learn.microsoft.com/en-us/power-apps/developer/data-platform/walkthrough-register-app-azure-active-directory for connection details.
# - Access to Outlook 365 with Service principle https://learn.microsoft.com/en-us/outlook/rest/get-started
# - Autogen : Refer https://microsoft.github.io/autogen/docs/Getting-Started
# - Read through Task Decomposition for understanding how to work with function calls in Agentic Architecture.
#
# ### Note : This is a sample approach and may not store the relevent details for Service Principles securily. Please follow your organization's guideline to handle secrets and enviroment variables.
#
# Author
# - Prateek Dhiman
# - Steve Vassallo
#
# Microsoft

# %%
# Uncomment to install once. It is recommended to install in a sepearte python environment or conda environment

#! pip install pyautogen
#! pip install requests

# %%
import time
import os 
from autogen import AssistantAgent, UserProxyAgent, config_list_from_json
from autogen.cache import Cache
from autogen.coding import DockerCommandLineCodeExecutor, LocalCommandLineCodeExecutor
from typing_extensions import Annotated
import autogen
from autogen.cache import Cache
from dotenv import load_dotenv

# %%
# Lets fetch the environment variables
# Load the .env file
load_dotenv('.env')
api_key = os.getenv('api_key')
api_base = os.getenv('api_base')
api_version = os.getenv('api_version')

# %% [markdown]
# ### LLM Configuations

# %%
# If the config list is small, example for this excerise, we can define it here. Else its recommended to use a json file.
# More details at https://microsoft.github.io/autogen/docs/topics/llm_configuration#oai_config_list-pattern 

#config_list = autogen.config_list_from_json(env_or_file="OAI_CONFIG_LIST", filter_dict={"tags": ["tool"]})
# Dont need filter as the model we are going to use models that support function calling.

config_list = [
  {
    "model": "gpt-4o",
    "api_type": "azure",
    "api_key": api_key,
    "base_url": api_base,
    "api_version": api_version
  },
  {
    "model": "gpt-35-turbo",
    "api_type": "azure",
    "api_key": api_key,
    "base_url": api_base,
    "api_version": api_version
  }
]

llm_config = {
    "config_list": config_list,
}

# %% [markdown]
# ### Agent Definition

# %%
# Agent that has access to only two functions. 

coder = autogen.AssistantAgent(
    name="chatbot",
    system_message="For coding tasks, only use the functions you have been provided with. You have a dynamics365_call and a office365_call function, these functions can and should be used in parallel. Reply TERMINATE when the task is done.",
    llm_config=llm_config,
)

# an agent that is intended to be used as a code executor.

os.makedirs("coding", exist_ok=True)
# Use DockerCommandLineCodeExecutor if docker is available to run the generated code.
# Using docker is safer than running the generated code directly.
# code_executor = DockerCommandLineCodeExecutor(work_dir="coding")
code_executor = LocalCommandLineCodeExecutor(work_dir="coding")

# create a UserProxyAgent instance named "user_proxy"
user_proxy = autogen.UserProxyAgent(
    name="user_proxy",
    system_message="A proxy for the user for executing code.",
    is_termination_msg=lambda x: x.get("content", "") and x.get("content", "").rstrip().endswith("TERMINATE"),
    human_input_mode="NEVER",
    max_consecutive_auto_reply=10,
    code_execution_config={"executor": code_executor},
)

# %% [markdown]
# ### Function Definitions
# 1) A function to call dynamics 365
# 2) A function to call office 365

# %%
# define functions according to the function description
# An example async function registered using register_for_llm and register_for_execution decorators

# Dynamics 365 function

@user_proxy.register_for_execution()
@coder.register_for_llm(description="Get the details associated with the given account name from dynamics 365 using WebAPI.")
async def dynamics365_call(account_name: Annotated[str, "Account Details ."]) -> str:

    from dotenv import load_dotenv
    import requests
    # Get the token and call service principle for Dynamics 365
    load_dotenv('.env')
    tenant_id = os.getenv('dynamicsSP_tenant_id')
    client_id = os.getenv('dynamicsSP_client_id')
    client_secret = os.getenv('dynamicsSP_client_secret')
    resource = os.getenv('dynamicsSP_resource')

    # OAuth 2.0 token endpoint  
    token_url = f'https://login.microsoftonline.com/{tenant_id}/oauth2/v2.0/token'  

    # Prepare the data for the token request  
    data = {  
        'grant_type': 'client_credentials',  
        'client_id': client_id,  
        'client_secret': client_secret,  
        'scope': f'{resource}.default'  
    } 

    # Request the token  
    response = requests.post(token_url, data=data)  
    response_data = response.json()  

    if 'access_token' in response_data:  
        access_token = response_data['access_token']  
        #print("Access token retrieved successfully.")  
    else:  
        print("Error retrieving access token:", response_data) 
    
        # Set the API endpoint for retrieving accounts  
    #api_url = f'{resource}/api/data/v9.0/accounts'  
    api_url = f'{resource}/api/data/v9.0/accounts?$select=name,accountid&$filter=contains(name,\'{account_name}\')'
    #api_url = f'{resource}/api/data/v8.2/accounts(46f4a2bf-e63e-ef11-8409-002248277599)?$select=name&$expand=createdby($select=fullname),createdonbehalfby($select=fullname),owninguser($select=fullname)'

    # Set the headers for the request  
    headers = {  
        'Authorization': f'Bearer {access_token}',  
        'Content-Type': 'application/json',  
        'OData-MaxVersion': '4.0',  
        'OData-Version': '4.0',  
    }  
    
    # Make the request to retrieve account details  
    response = requests.get(api_url, headers=headers)  
    #accounts = response.json()  
    
    return response.json()

# %%
@user_proxy.register_for_execution()
@coder.register_for_llm(description="Get the emails associated with the given user and account name from outlook365.")
async def outlook365_call(account_name: Annotated[str, "Emails Details ."]) -> str:

    import requests
    from dotenv import load_dotenv
    load_dotenv('.env')

    client_id = os.getenv('outlookSP_client_id')
    tenant_id = os.getenv('outlookSP_tenant_id')
    client_secret = os.getenv('outlookSP_client_secret')
    scope = os.getenv('outlookSP_scope')
 
    # Get the access token
    url = f'https://login.microsoftonline.com/{tenant_id}/oauth2/v2.0/token'
    data = {
        'grant_type': 'client_credentials',
        'client_id': client_id,
        'client_secret': client_secret,
        'scope': scope
    }
    response = requests.post(url, data=data)
    access_token = response.json().get('access_token')
    
    # print(response)
    # print(access_token)

    user_id = '0f3ba324-d6a4-477e-8fea-bc90750ad285'  # Replace with the actual user ID
    url = f"https://graph.microsoft.com/v1.0/users/{user_id}/mailFolders/inbox/messages"
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Content-Type': 'application/json'
    }
    params = {
        #'$search': 'Alpine',
        '$search': f'"{account_name}"',
        '$select': 'subject,body,receivedDateTime'
    }
    
    response = requests.get(url, headers=headers, params=params)
    #print(response.status_code)
    #print(response.json())
    return response.json()
# Out:
# c:\Users\pdhiman\Anaconda3\envs\pimco\lib\site-packages\autogen\agentchat\conversable_agent.py:2490: UserWarning: Function 'outlook365_call' is being overridden.
#   warnings.warn(f"Function '{tool_sig['function']['name']}' is being overridden.", UserWarning)
# c:\Users\pdhiman\Anaconda3\envs\pimco\lib\site-packages\autogen\agentchat\conversable_agent.py:2409: UserWarning: Function 'outlook365_call' is being overridden.
#   warnings.warn(f"Function '{name}' is being overridden.", UserWarning)

# %% [markdown]
# ### Initiate a simple chat for testing the above agents

# %%
with Cache.disk() as cache:
    await user_proxy.a_initiate_chat(  # noqa: F704
        coder,
        message="Find the details for account Alpine Ski House and associated emails .",
        cache=cache,
    )
# Out:
# user_proxy (to chatbot):
#
# Find the details for account Alpine Ski House and associated emails .
#
# --------------------------------------------------------------------------------
# chatbot (to user_proxy):
#
# ***** Suggested tool call (call_baqsVljQ65r3jhv7OXR0oKeP): dynamics365_call *****
# Arguments:
# {"account_name": "Alpine Ski House"}
# *********************************************************************************
# ***** Suggested tool call (call_3WJMGj1cAKoOuYK0lbPub9XT): outlook365_call *****
# Arguments:
# {"account_name": "Alpine Ski House"}
# ********************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING ASYNC FUNCTION dynamics365_call...
#
# >>>>>>>> EXECUTING ASYNC FUNCTION outlook365_call...
# user_proxy (to chatbot):
#
# user_proxy (to chatbot):
#
# ***** Response from calling tool (call_baqsVljQ65r3jhv7OXR0oKeP) *****
# {"@odata.context": "https://orgd4e65928.crm.dynamics.com/api/data/v9.0/$metadata#accounts(name,accountid)", "value": [{"@odata.etag": "W/\"6379902\"", "name": "Alpine Ski House (sample)", "accountid": "46f4a2bf-e63e-ef11-8409-002248277599"}]}
# **********************************************************************
#
# --------------------------------------------------------------------------------
# user_proxy (to chatbot):
#
# ***** Response from calling tool (call_3WJMGj1cAKoOuYK0lbPub9XT) *****
# {"@odata.context": "https://graph.microsoft.com/v1.0/$metadata#users('0f3ba324-d6a4-477e-8fea-bc90750ad285')/mailFolders('inbox')/messages(subject,body,receivedDateTime)", "value": [{"@odata.etag": "W/\"CQAAABYAAAAW7kwrgry4QYwXzkQhOoIkAAANcca7\"", "id": "AAMkAGU5MWY0NWZjLThhNmYtNGYyNS1iOTZkLTQ0NWFkOTVlYmU2NgBGAAAAAAD4GSQPmfDbRb9R0rNQUHQiBwAW7kwrgry4QYwXzkQhOoIkAAAAAAEMAAAW7kwrgry4QYwXzkQhOoIkAAANdb3SAAA=", "receivedDateTime": "2024-07-31T13:45:25Z", "subject": "Alpine Ski House - Catalog Expansion", "body": {"contentType": "html", "content": "<html><head>\r\n<meta http-equiv=\"Content-Type\" content=\"text/html; charset=utf-8\"><style type=\"text/css\" style=\"display:none\">\r\n<!--\r\np\r\n\t{margin-top:0;\r\n\tmargin-bottom:0}\r\n-->\r\n</style></head><body dir=\"ltr\"><div class=\"elementToProof\" style=\"font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)\">We are interested&nbsp;in expanding products in our catalog and curious about products that are similar to SKU JJ202.</div><div class=\"elementToProof\" style=\"font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)\"><br></div><div class=\"elementToProof\" style=\"font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)\">We have been doing business with you for decades and would like to know how we can get better pricing, especially with this larger than normal order we are considering.&nbsp;</div><div class=\"elementToProof\" style=\"font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)\"><br></div><div class=\"elementToProof\" style=\"font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)\">Thanks,&nbsp;</div><div class=\"elementToProof\" style=\"font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)\">Paul Cannon</div><div id=\"Signature\"><p>&nbsp;</p></div></body></html>"}}]}
# **********************************************************************
#
# --------------------------------------------------------------------------------
# chatbot (to user_proxy):
#
# ### Account Details:
# - **Name**: Alpine Ski House (sample)
# - **Account ID**: 46f4a2bf-e63e-ef11-8409-002248277599
#
# ### Associated Emails:
# 1. **Subject**: Alpine Ski House - Catalog Expansion
#    - **Received Date**: 2024-07-31T13:45:25Z
#    - **Content**:
#      ```html
#      <html><head>
#      <meta http-equiv="Content-Type" content="text/html; charset=utf-8"><style type="text/css" style="display:none">
#      <!--
#      p
#          {margin-top:0;
#          margin-bottom:0}
#      -->
#      </style></head><body dir="ltr"><div class="elementToProof" style="font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)">We are interested&nbsp;in expanding products in our catalog and curious about products that are similar to SKU JJ202.</div><div class="elementToProof" style="font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)"><br></div><div class="elementToProof" style="font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)">We have been doing business with you for decades and would like to know how we can get better pricing, especially with this larger than normal order we are considering.&nbsp;</div><div class="elementToProof" style="font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)"><br></div><div class="elementToProof" style="font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)">Thanks,&nbsp;</div><div class="elementToProof" style="font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)">Paul Cannon</div><div id="Signature"><p>&nbsp;</p></div></body></html>
#      ```
#
# TERMINATE
#
# --------------------------------------------------------------------------------

# %% [markdown]
# #### Lets make the responses well formatted by using a formating / markdown agent.

# %%
markdownagent = autogen.AssistantAgent(
    name="Markdown_agent",
    system_message="Respond in markdown only",
    llm_config=llm_config,
)

# Add a function for robust group chat termination


@user_proxy.register_for_execution()
@markdownagent.register_for_llm()
@coder.register_for_llm(description="terminate the group chat")
def terminate_group_chat(message: Annotated[str, "Message to be sent to the group chat."]) -> str:
    return f"[GROUPCHAT_TERMINATE] {message}"


groupchat = autogen.GroupChat(agents=[user_proxy, coder, markdownagent], messages=[], max_round=12)

llm_config_manager = llm_config.copy()
llm_config_manager.pop("functions", None)
llm_config_manager.pop("tools", None)

manager = autogen.GroupChatManager(
    groupchat=groupchat,
    llm_config=llm_config_manager,
    is_termination_msg=lambda x: "GROUPCHAT_TERMINATE" in x.get("content", ""),
)
# Out:
# c:\Users\pdhiman\Anaconda3\envs\pimco\lib\site-packages\autogen\agentchat\conversable_agent.py:2490: UserWarning: Function 'terminate_group_chat' is being overridden.
#   warnings.warn(f"Function '{tool_sig['function']['name']}' is being overridden.", UserWarning)
# c:\Users\pdhiman\Anaconda3\envs\pimco\lib\site-packages\autogen\agentchat\conversable_agent.py:2409: UserWarning: Function 'terminate_group_chat' is being overridden.
#   warnings.warn(f"Function '{name}' is being overridden.", UserWarning)

# %% [markdown]
# #### Initiating a agent conversation.

# %%
message = """
1) Find the details for account Alpine Ski House and associated emails.
2) Pretty print the result as md.
3) Based on the email and account information, what should be the sales strategy for upcoming call.
4) when 1,2 and 3 are done, terminate the group chat
"""

with Cache.disk() as cache:
    await user_proxy.a_initiate_chat(  # noqa: F704
        manager,
        message=message,
        cache=cache,
    )
# Out:
# user_proxy (to chat_manager):
#
#
# 1) Find the details for account Alpine Ski House and associated emails.
# 2) Pretty print the result as md.
# 3) Based on the email and account information, what should be the sales strategy for upcoming call.
# 4) when 1,2 and 3 are done, terminate the group chat
#
#
# --------------------------------------------------------------------------------
# chatbot (to chat_manager):
#
# ***** Suggested tool call (call_bZgnpKJkHAJpRE6HnTW4cDsV): dynamics365_call *****
# Arguments:
# {"account_name": "Alpine Ski House"}
# *********************************************************************************
# ***** Suggested tool call (call_U2IFHkVJSaPRc10qGFJHUJwo): outlook365_call *****
# Arguments:
# {"account_name": "Alpine Ski House"}
# ********************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING ASYNC FUNCTION dynamics365_call...
#
# >>>>>>>> EXECUTING ASYNC FUNCTION outlook365_call...
# user_proxy (to chat_manager):
#
# user_proxy (to chat_manager):
#
# ***** Response from calling tool (call_bZgnpKJkHAJpRE6HnTW4cDsV) *****
# {"@odata.context": "https://orgd4e65928.crm.dynamics.com/api/data/v9.0/$metadata#accounts(name,accountid)", "value": [{"@odata.etag": "W/\"6379902\"", "name": "Alpine Ski House (sample)", "accountid": "46f4a2bf-e63e-ef11-8409-002248277599"}]}
# **********************************************************************
#
# --------------------------------------------------------------------------------
# user_proxy (to chat_manager):
#
# ***** Response from calling tool (call_U2IFHkVJSaPRc10qGFJHUJwo) *****
# {"@odata.context": "https://graph.microsoft.com/v1.0/$metadata#users('0f3ba324-d6a4-477e-8fea-bc90750ad285')/mailFolders('inbox')/messages(subject,body,receivedDateTime)", "value": [{"@odata.etag": "W/\"CQAAABYAAAAW7kwrgry4QYwXzkQhOoIkAAANcca7\"", "id": "AAMkAGU5MWY0NWZjLThhNmYtNGYyNS1iOTZkLTQ0NWFkOTVlYmU2NgBGAAAAAAD4GSQPmfDbRb9R0rNQUHQiBwAW7kwrgry4QYwXzkQhOoIkAAAAAAEMAAAW7kwrgry4QYwXzkQhOoIkAAANdb3SAAA=", "receivedDateTime": "2024-07-31T13:45:25Z", "subject": "Alpine Ski House - Catalog Expansion", "body": {"contentType": "html", "content": "<html><head>\r\n<meta http-equiv=\"Content-Type\" content=\"text/html; charset=utf-8\"><style type=\"text/css\" style=\"display:none\">\r\n<!--\r\np\r\n\t{margin-top:0;\r\n\tmargin-bottom:0}\r\n-->\r\n</style></head><body dir=\"ltr\"><div class=\"elementToProof\" style=\"font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)\">We are interested&nbsp;in expanding products in our catalog and curious about products that are similar to SKU JJ202.</div><div class=\"elementToProof\" style=\"font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)\"><br></div><div class=\"elementToProof\" style=\"font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)\">We have been doing business with you for decades and would like to know how we can get better pricing, especially with this larger than normal order we are considering.&nbsp;</div><div class=\"elementToProof\" style=\"font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)\"><br></div><div class=\"elementToProof\" style=\"font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)\">Thanks,&nbsp;</div><div class=\"elementToProof\" style=\"font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)\">Paul Cannon</div><div id=\"Signature\"><p>&nbsp;</p></div></body></html>"}}]}
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Markdown_agent (to chat_manager):
#
# ### Account Details: Alpine Ski House
#
# #### Account Information
# - **Name**: Alpine Ski House (sample)
# - **Account ID**: 46f4a2bf-e63e-ef11-8409-002248277599
#
# #### Associated Emails
# - **Email Subject**: Alpine Ski House - Catalog Expansion
# - **Received Date**: 2024-07-31
# - **Email Body**:
#     ```html
#     <div style="font-family:&quot;Segoe UI&quot;,sans-serif; font-size:12pt; color:rgb(78,149,217)">
#     We are interested&nbsp;in expanding products in our catalog and curious about products that are similar to SKU JJ202.<br><br>
#     We have been doing business with you for decades and would like to know how we can get better pricing, especially with this larger than normal order we are considering.
#     <br><br>
#     Thanks,&nbsp;<br>
#     Paul Cannon
#     </div>
#     ```
#
# ### Sales Strategy for Upcoming Call
# Based on the email and account details, here are some strategies for the upcoming call:
# 1. **Acknowledge their Long-Term Relationship**:
#    - Appreciate the decades-long business relationship and express the value of their loyalty.
#
# 2. **Offer Tailored Solutions**:
#    - Discuss products similar to SKU JJ202 that could fit their catalog expansion needs.
#    - Highlight any new arrivals or best sellers that may interest them.
#
# 3. **Flexible Pricing and Discounts**:
#    - present special pricing options especially for large orders, emphasizing on bulk order discounts or personalized pricing.
#
# 4. **Customization and Additional Services**:
#    - Explore possibilities for custom services or product bundling that cater specifically to their expansion plans.
#
# 5. **Scheduled Follow-Ups**:
#    - Set clear follow-up actions and timelines for addressing their requirements and concerns.
#
# ### Terminating the Group Chat
#
# I'll now proceed to terminate the group chat.
# ***** Suggested tool call (call_z6c2eirDiac5FemChKTscoMd): terminate_group_chat *****
# Arguments:
# {"message":"The required information has been retrieved and the strategies have been planned. Terminating the group chat now."}
# *************************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING ASYNC FUNCTION terminate_group_chat...
# user_proxy (to chat_manager):
#
# user_proxy (to chat_manager):
#
# ***** Response from calling tool (call_z6c2eirDiac5FemChKTscoMd) *****
# [GROUPCHAT_TERMINATE] The required information has been retrieved and the strategies have been planned. Terminating the group chat now.
# **********************************************************************
#
# --------------------------------------------------------------------------------
